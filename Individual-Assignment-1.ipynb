# %%
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: <object object at 0x000001E2B3D3F0C0>
# Populating the interactive namespace from numpy and matplotlib

# %%
from PIL import Image
img = np.array(Image.open('horse.jpg'))
img = img.astype(float)/255.
plt.imshow(img)

# %%
import segmentation
seg = segmentation.graph_based_segmentation(img)

import kmeans
y = kmeans.kmeans_with_color_posn(img, 2, 0.1)
# Out:
# Iteration 0: 8736.445029
# Iteration 1: 5104.825795
# Iteration 2: 4580.818938
# Iteration 3: 4545.099147
# Iteration 4: 4541.993355
# Iteration 5: 4538.285399

# %%
plt.figure(); plt.imshow(y, cmap=plt.get_cmap('gray'))

# %%
plt.figure(); plt.imshow(seg, cmap=plt.get_cmap('gray'))

# %%
# We need a good threshold, since the eigenvector has continuous real values. 
# this threshold has been tuned for the 'horse' image
cluster1 = seg>-0.005
cluster2 = seg<=-0.005

plt.figure(); plt.imshow(cluster1, cmap=plt.get_cmap('gray'))
plt.figure(); plt.imshow(cluster2, cmap=plt.get_cmap('gray'))
